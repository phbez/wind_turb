# %% [markdown]
# <a href="https://colab.research.google.com/github/LeticiaVieirg/crack_thermal_detection/blob/main/Small_Wind_Turbine_Blade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Importação das bibliotecas

# %%
import tensorflow as tf
import cv2
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten, BatchNormalization, Activation, Add, Input, AveragePooling2D
from keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import regularizers

import numpy as np
import os, sys
from scipy import ndimage
import cv2
import matplotlib.pyplot as plt
import itertools
import scipy.stats

from keras import applications, optimizers, Input
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score
from sklearn.utils.multiclass import unique_labels

# %% [markdown]
# 2. Carregando o dataset

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# Load the dataset from a Google Drive folder as ZIP file
import os
import gdown
import zipfile

# Create data directories
DATA_DIR = os.path.join(os.getcwd(), 'data')
DATASET_DIR = os.path.join(DATA_DIR, 'dataset')
os.makedirs(DATASET_DIR, exist_ok=True)

# Google Drive ZIP file ID (replace with the ZIP file ID)
#zip_file_id = '16-pPc_hHPbDLxnNE0gR88zhuKSJ6vGz4' #metal surfaces dataset
zip_file_id = '1-m_pvu89ZYzqZ3Utg_xa5sKemCFNe1B4' #small wind turbines dataset

# Output path
output_path = os.path.join(DATASET_DIR, 'dataset.zip')

# Download from Google Drive
url = f'https://drive.google.com/uc?id={zip_file_id}'
gdown.download(url, output_path, quiet=False)

# Unzip the downloaded file
with zipfile.ZipFile(output_path, 'r') as zip_ref:
    zip_ref.extractall(DATASET_DIR)

print(f"Downloaded and extracted to {DATASET_DIR}")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1-m_pvu89ZYzqZ3Utg_xa5sKemCFNe1B4
# From (redirected): https://drive.google.com/uc?id=1-m_pvu89ZYzqZ3Utg_xa5sKemCFNe1B4&confirm=t&uuid=a4c55a87-3cee-4261-ae62-efc0c9c1e198
# To: c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\wind_Turbine\data\dataset\dataset.zip
# 100%|██████████| 125M/125M [00:34<00:00, 3.63MB/s]
# Downloaded and extracted to c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\wind_Turbine\data\dataset

# %%
#folder='/content/drive/Shareddrives/Letícia Vieira Gonçalves - Pesquisa/dataset/CAI-SWTB-Dataset/Train'

folder = os.path.join(DATASET_DIR) # DATASET_DIR was defined in the prior cell.

# %% [markdown]
# 3. Estruturando o dataset

# %%
#image resolution
image_width = 48
image_height = 48
channels = 3 #rgb

train_files = []
i=0
for classes in ['Faulty', 'Healthy']:
    print(os.path.join(folder, classes))
    onlyfiles = [f for f in os.listdir(os.path.join(folder, classes)) if os.path.isfile(os.path.join(folder, classes, f ))]
    for _file in onlyfiles:
        train_files.append(_file)

dataset = np.ndarray(shape=(len(train_files), image_height, image_width, channels),
                     dtype=np.float32)
y_dataset = []
# Out:
# c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\wind_Turbine\data\dataset\Faulty
# c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\wind_Turbine\data\dataset\Healthy

# %%
from PIL import Image
from keras.utils import load_img, img_to_array

i = 0

valid_extensions=(".jpg", ".jpeg", ".png", ".bmp")

for classes in ['Faulty', 'Healthy']: #catregorias das imagens
    onlyfiles = [f for f in os.listdir(os.path.join(folder, classes))
     if f.lower().endswith(valid_extensions) and
             os.path.isfile(os.path.join(folder, classes, f))]

    #if os.path.isfile(os.path.join(folder, classes, f))] #seleciona as imagens e ignora pastas
    for _file in onlyfiles: #Percorre os arquivos da pasta
        img_path = os.path.join(folder, classes, _file)
        img = load_img(img_path, target_size=(image_height, image_width)) #redimenciona a iamgem
        x = img_to_array(img)

        dataset[i] = x #armazenando os dados
        mapping = {'Faulty': 0 , 'Healthy': 1} #dicionario
        y_dataset.append(mapping[classes])  #rotulo das imagens

        i += 1
        if i == 30000:
            print("%d images to array" % i)
            break

print("All images to array!")
# Out:
# All images to array!

# %% [markdown]
# 6. Normalizando os dados

# %%
#Normalização
dataset = dataset.astype('float32')
dataset /= 255

# %%
classes = ['Faulty', 'Healthy']

# Dicionário para armazenar o índice da primeira imagem de cada classe
first_image_index = {}

# Encontra o índice da primeira imagem de cada classe
for i, label in enumerate(y_dataset):
    if label not in first_image_index:
        first_image_index[label] = i

# Configura a grade para exibir as imagens
num_classes = len(set(y_dataset))
num_images_per_class = 1
num_cols = num_classes
num_rows = num_images_per_class

# %%
# Cria uma figura com uma grade de subplots

print(num_rows, num_cols)
fig, axes = plt.subplots(num_rows, num_cols, figsize=(5, 15))

# Loop através de cada classe
for i in range(num_classes):
    # Obtém o índice da primeira imagem da classe
    idx = first_image_index[i]

    # Obtém a imagem e converte para RGB
    pixels = dataset[idx]

    # Exibe a imagem no subplot correspondente
    axes[i].imshow(pixels, cmap='Spectral')
    axes[i].axis('off')

    # Adiciona um título para o subplot com o rótulo
    axes[i].set_title(f'{classes[i]}')

# Exibe a figura
plt.tight_layout()
plt.show()
# Out:
# 1 2

# %% [markdown]
# 7. Normalizando o dataset

# %%
# categorical values
n_classes = len(set(y_dataset))
print(n_classes)

y_dataset_ = to_categorical(y_dataset, n_classes)
# Out:
# 2

# %%
# Ajusta o tamanho do dataset para coincidir com o tamanho menor entre dataset_trimmed e y_dataset_
min_length = min(len(dataset), len(y_dataset_))
dataset_trimmed = dataset[:min_length]
y_dataset_trimmed = y_dataset_[:min_length]

# Verifica se os tamanhos agora estão iguais
assert len(dataset_trimmed) == len(y_dataset_trimmed), "Os tamanhos ainda não são consistentes!"

# Dividindo em conjuntos de treino e teste
X_train, X_test, y_train, y_test = train_test_split(dataset_trimmed, y_dataset_trimmed, test_size=0.2)

print("Train set size: {}, Test set size: {}".format(len(X_train), len(X_test)))
# Out:
# Train set size: 3360, Test set size: 840

# %%
from sklearn.utils import resample

# Criar listas vazias para armazenar as amostras balanceadas
balanced_X_train = []
balanced_y_train = []

# Determinar o número de amostras na classe majoritária
majority_samples = 5000

# Iterar sobre cada classe
for class_label in np.unique(y_train.argmax(axis=1)):
    # Filtrar amostras pertencentes a essa classe
    X_class = X_train[y_train.argmax(axis=1) == class_label]
    y_class = y_train[y_train.argmax(axis=1) == class_label]

    # Calcular o número de amostras na classe menos representada
    minority_samples = len(X_class)

    # Balancear as amostras aumentando a classe menos representada
    balanced_X_class, balanced_y_class = resample(X_class, y_class,
                                                  replace=True,
                                                  n_samples=majority_samples,
                                                  random_state=42)

    # Adicionar amostras balanceadas à lista
    balanced_X_train.extend(balanced_X_class)
    balanced_y_train.extend(balanced_y_class)

# Converter listas em arrays numpy
balanced_X_train = np.array(balanced_X_train)
balanced_y_train = np.array(balanced_y_train)

# Embaralhar amostras
shuffled_indices = np.arange(len(balanced_X_train))
np.random.shuffle(shuffled_indices)
balanced_X_train = balanced_X_train[shuffled_indices]
balanced_y_train = balanced_y_train[shuffled_indices]

# Verificar o tamanho dos conjuntos de dados balanceados
print("Tamanho do conjunto de treinamento balanceado:", len(balanced_X_train))
print("Tamanho do conjunto de teste:", len(X_test))

for class_label in np.unique(balanced_y_train.argmax(axis=1)):
    count = np.sum(balanced_y_train.argmax(axis=1) == class_label)
    print(f"Classe {class_label}: {count} amostras")
# Out:
# Tamanho do conjunto de treinamento balanceado: 10000
# Tamanho do conjunto de teste: 840
# Classe 0: 5000 amostras
# Classe 1: 5000 amostras

# %%
# Criar o modelo
model = Sequential()

model.add(BatchNormalization(input_shape=(image_height, image_width, 3)))
model.add(Conv2D(512, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.2))  # Adiciona a camada de dropout

model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.2))  # Adiciona a camada de dropout

model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.2))  # Adiciona a camada de dropout
model.add(Dense(2, activation='softmax'))  # Especifica 'softmax' como a função de ativação

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization_1           │ (None, 48, 48, 3)      │            12 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 48, 48, 512)    │        14,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 24, 24, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 24, 24, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 256)    │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 12, 12, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 36864)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │     1,179,680 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,373,998 (9.06 MB)
#  Trainable params: 2,373,992 (9.06 MB)
#  Non-trainable params: 6 (24.00 B)

# %% [markdown]
# 4. Compilando o modelo

# %%
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Treinando o modelo
from tensorflow.keras.callbacks import EarlyStopping

# Configurar EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# Treinar o modelo
history = model.fit(balanced_X_train, balanced_y_train,validation_split= 0.2, epochs=100, callbacks=[early_stopping], batch_size=64)
# Out:
# Epoch 1/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 124s 984ms/step - accuracy: 0.5807 - loss: 0.7626 - val_accuracy: 0.6185 - val_loss: 0.6387
# Epoch 2/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 129s 1s/step - accuracy: 0.7306 - loss: 0.5268 - val_accuracy: 0.7270 - val_loss: 0.5338
# Epoch 3/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 130s 1s/step - accuracy: 0.7765 - loss: 0.4561 - val_accuracy: 0.7760 - val_loss: 0.4451
# Epoch 4/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 119s 953ms/step - accuracy: 0.8262 - loss: 0.3805 - val_accuracy: 0.8665 - val_loss: 0.3173
# Epoch 5/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 119s 953ms/step - accuracy: 0.8540 - loss: 0.3347 - val_accuracy: 0.8630 - val_loss: 0.3209
# Epoch 6/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 121s 968ms/step - accuracy: 0.8751 - loss: 0.3064 - val_accuracy: 0.9045 - val_loss: 0.2531
# Epoch 7/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 122s 972ms/step - accuracy: 0.8812 - loss: 0.2803 - val_accuracy: 0.9025 - val_loss: 0.2454
# Epoch 8/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 120s 962ms/step - accuracy: 0.8878 - loss: 0.2648 - val_accuracy: 0.9275 - val_loss: 0.1989
# Epoch 9/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 121s 966ms/step - accuracy: 0.9100 - loss: 0.2174 - val_accuracy: 0.9345 - val_loss: 0.1752
# Epoch 10/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 122s 972ms/step - accuracy: 0.9128 - loss: 0.2080 - val_accuracy: 0.9210 - val_loss: 0.2038
# Epoch 11/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 126s 1s/step - accuracy: 0.9115 - loss: 0.2059 - val_accuracy: 0.9440 - val_loss: 0.1627
# Epoch 12/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 122s 978ms/step - accuracy: 0.9228 - loss: 0.1907 - val_accuracy: 0.9470 - val_loss: 0.1498
# Epoch 13/100
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 115s 923ms/step - accuracy: 0.9299 - loss: 0.1708 - val_accuracy: 0.9360 - val_loss: 0.1791
# Epoch 14/100
#  14/125 ━━━━━━━━━━━━━━━━━━━━ 1:40 902ms/step - accuracy: 0.9060 - loss: 0.2115
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 8
#       5 early_stopping = EarlyStopping(monitor='val_loss', patience=10)
#       7 # Treinar o modelo
# ----> 8 history = model.fit(balanced_X_train, balanced_y_train,validation_split= 0.2, epochs=100, callbacks=[early_stopping], batch_size=64)
#
# File c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\ph119\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\ph119\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\ph119\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\ph119\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\ph119\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\ph119\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\ph119\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\ph119\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\ph119\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\ph119\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\ph119\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File c:\Users\Paulo\OneDrive\Área de Trabalho\Repository\crack_thermal_detection\ph119\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
val_accuracy = history.history['val_accuracy']

mean_val_accuracy = np.mean(val_accuracy)

print("Valor médio de acurácia:", mean_val_accuracy)
# Out:
# Valor médio de acurácia: 0.9952261774312883

# %% [markdown]
# 5. Carregando o modelo

# %%
import pandas as pd
history_save = pd.DataFrame(history.history)
history_save.to_csv('datasetCAI.csv')

# %%
# save model structure in jason file
model_json = model.to_json()
with open("CAImodel.json", "w") as json_file:
    json_file.write(model_json)

# %%
model.save('modeloCAI.keras')

# %%
from keras.models import load_model

modelo_carregado = load_model('/content/modeloCAI.keras')

# %%
import pandas as pd

history = pd.read_csv('/content/datasetCAI.csv')

# %% [markdown]
# 6. Plotando o modelo

# %%
import matplotlib.pyplot as plt

plt.plot(history['loss'])
plt.plot(history['val_loss'])


plt.ylabel('Perda')
plt.xlabel('Época')
plt.legend(['Treinamento', 'Validação'], loc = 'upper right')
plt.show()

# %%
plt.plot(history['accuracy'])
plt.plot(history['val_accuracy'])
plt.title('Acurácia')
plt.ylabel('Acurácia')
plt.xlabel('Épocas')
plt.legend(['Treinamento', 'Validação'], loc='upper left')
plt.grid(True)
plt.show()
plt.close()

# %% [markdown]
# 7. Salvando o modelo

# %%
preds = modelo_carregado.predict(X_test)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step

# %%
#Função da Matriz de Confusão

def plot_confusion_matrix(
        cm,
        classes,
        normalize=False,
        title='Confusion matrix',
        cmap=plt.cm.Blues
    ):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    #plt.title(title)
    #plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Classe real')
    plt.xlabel('Classe predita')

# %%
#Gráfico da Matriz de Confusão

y_test_ = [np.argmax(x) for x in y_test]
preds_ = [np.argmax(x) for x in preds]

cm = confusion_matrix(y_test_, preds_)
plot_confusion_matrix(cm, classes=['Positive', 'Negative Positive'], title='Confusion matrix')
plt.show()
plt.close()
# Out:
# Confusion matrix, without normalization
# [[ 40   5]
#  [  2 423]]

# %%
#Resultado das predições

n = 4
for t in range(4):
    plt.figure(figsize=(10,10))
    for i in range(n*t, n*(t+1)):
        plt.subplot(1, n, i + 1 - n*t)
        plt.imshow(cv2.cvtColor(X_test[i], cv2.COLOR_BGR2RGB), cmap='gray')
        plt.title('Real: {}\nPredito: {}'.format(classes[np.argmax(y_test[i])], classes[np.argmax(preds[i])]))
        plt.axis('off')
    plt.show()

# %% [markdown]
# ========================================================================================

# %% [markdown]
# Testes

# %% [markdown]
# Carregar o modelo salvo

# %%
from keras.models import load_model

modelo = load_model("modeloCAI.keras")  # Ajuste o caminho se necessário

# %% [markdown]
# Pre-processamento de uma imagem e classificação

# %%
def preprocessar_imagem(caminho_imagem):
    image_width, image_height = 48, 48  # Tamanho usado no treinamento
    img = cv2.imread(caminho_imagem)
    img = cv2.resize(img, (image_width, image_height))
    img = img.astype("float32") / 255.0  # Normalização
    img = np.expand_dims(img, axis=0)  # Adicionar batch dimension
    return img

# %%
caminho_imagem = "/content/drive/Shareddrives/Letícia Vieira Gonçalves - Pesquisa/dataset/CAI-SWTB-Dataset/Test/Test/Test/Faulty_11.jpg"
imagem = preprocessar_imagem(caminho_imagem)

predicao = modelo.predict(imagem)
classe_predita = np.argmax(predicao)  # Obtém a classe com maior probabilidade

# Mapeamento das classes
mapping = {0: "Faulty", 1: "Healthy"}
print("Classe Predita:", mapping[classe_predita])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 840ms/step
# Classe Predita: Faulty

# %% [markdown]
# Teste com a Pasta Test

# %%
pasta_imagens = "/content/drive/Shareddrives/Letícia Vieira Gonçalves - Pesquisa/dataset/CAI-SWTB-Dataset/Test/Test/Test"  # Substitua pelo caminho correto
valid_extensions = (".jpg", ".jpeg", ".png", ".bmp")

# Mapeamento das classes
mapping = {0: "Faulty", 1: "Healthy"}

# Percorrer todas as imagens da pasta
for nome_arquivo in os.listdir(pasta_imagens):
    if nome_arquivo.lower().endswith(valid_extensions):  # Verifica se é uma imagem
        caminho_imagem = os.path.join(pasta_imagens, nome_arquivo)

        # Pré-processar a imagem
        imagem = preprocessar_imagem(caminho_imagem)

        # Fazer a predição
        predicao = modelo.predict(imagem)
        classe_predita = np.argmax(predicao)  # Obtém a classe com maior probabilidade

        print(f"Imagem: {nome_arquivo} -> Classe Predita: {mapping[classe_predita]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_277.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Imagem: Faulty_271.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Imagem: Faulty_302.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_228.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_131.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Imagem: Faulty_287.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Imagem: Faulty_16.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_24.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Faulty_194.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Faulty_112.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_127.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Faulty_223.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_19.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_232.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_179.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_225.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Faulty_305.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Faulty_199.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_151.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_176.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Faulty_185.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_137.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_156.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_181.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_308.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_214.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_168.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_170.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Faulty_205.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_22.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Imagem: Faulty_230.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Faulty_256.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Faulty_197.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_118.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_115.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_11.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_13.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_289.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_202.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_158.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_311.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_192.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_275.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_267.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_280.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_294.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Imagem: Faulty_146.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Faulty_75.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Imagem: Faulty_402.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Faulty_338.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Healthy_104.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Imagem: Faulty_463.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Imagem: Faulty_439.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Faulty_477.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Faulty_500.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Faulty_385.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Faulty_362.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Imagem: Faulty_344.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Faulty_414.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Faulty_437.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Faulty_379.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Imagem: Faulty_313.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Faulty_461.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Imagem: Faulty_373.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Faulty_381.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Imagem: Faulty_37.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Imagem: Faulty_316.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Imagem: Faulty_485.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Imagem: Faulty_90.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Imagem: Faulty_384.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Imagem: Faulty_320.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Imagem: Faulty_431.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Faulty_494.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Faulty_473.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Imagem: Faulty_371.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Imagem: Faulty_433.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# Imagem: Faulty_339.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Imagem: Faulty_354.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Imagem: Faulty_410.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Imagem: Faulty_70.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Imagem: Faulty_472.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Faulty_425.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Faulty_404.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_59.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_40.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_315.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_77.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_466.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Faulty_85.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_427.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_359.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_420.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_47.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_35.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_363.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Imagem: Faulty_369.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_317.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_57.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_352.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_396.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Imagem: Faulty_45.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Imagem: Healthy_349.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_199.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_324.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_187.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_125.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_14.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_288.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_303.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_129.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_171.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_272.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_204.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Healthy_253.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_181.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Imagem: Healthy_252.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_146.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_156.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_321.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_226.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_286.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_115.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_140.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_344.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_162.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_276.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_3.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Healthy_150.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_16.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_185.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_222.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Healthy_32.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_166.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_267.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_213.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_142.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_247.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_242.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_238.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Imagem: Healthy_263.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_227.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_220.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Healthy_323.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_315.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_270.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Healthy_342.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_161.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_28.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_34.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_23.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Healthy_117.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Imagem: Healthy_130.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_338.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_245.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Healthy_195.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Imagem: Healthy_256.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_396.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_75.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_38.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_497.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_420.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_500.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Imagem: Healthy_63.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_9.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_35.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Healthy_360.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_472.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_39.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_461.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_352.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_480.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Imagem: Healthy_464.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_85.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_375.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_47.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Imagem: Healthy_401.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_359.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Imagem: Healthy_415.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_366.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_374.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Imagem: Healthy_96.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_433.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_486.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_398.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_382.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Healthy_418.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_478.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_474.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_395.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_434.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_489.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_466.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_473.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_381.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_356.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_8.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_413.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_83.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Imagem: Healthy_445.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Healthy_404.jpg -> Classe Predita: Faulty

# %% [markdown]
# Teste com arquivos da pasta Validation

# %%
pasta_imagens = "/content/drive/Shareddrives/Letícia Vieira Gonçalves - Pesquisa/dataset/CAI-SWTB-Dataset/Test/Test/Validation/Faulty"  # Substitua pelo caminho correto
valid_extensions = (".jpg", ".jpeg", ".png", ".bmp")

# Mapeamento das classes
mapping = {0: "Faulty", 1: "Healthy"}

# Percorrer todas as imagens da pasta
for nome_arquivo in os.listdir(pasta_imagens):
    if nome_arquivo.lower().endswith(valid_extensions):  # Verifica se é uma imagem
        caminho_imagem = os.path.join(pasta_imagens, nome_arquivo)

        # Pré-processar a imagem
        imagem = preprocessar_imagem(caminho_imagem)

        # Fazer a predição
        predicao = modelo.predict(imagem)
        classe_predita = np.argmax(predicao)  # Obtém a classe com maior probabilidade

        print(f"Imagem: {nome_arquivo} -> Classe Predita: {mapping[classe_predita]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty110.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty193.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty118.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Imagem: Areial_Faulty165.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Imagem: Areial_Faulty134.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# Imagem: Areial_Faulty321.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Imagem: Areial_Faulty513.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Imagem: Areial_Faulty696.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Imagem: Areial_Faulty280.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# Imagem: Areial_Faulty526.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# Imagem: Areial_Faulty5.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Imagem: Areial_Faulty230.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Imagem: Areial_Faulty711.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# Imagem: Areial_Faulty57.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Imagem: Areial_Faulty527.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# Imagem: Areial_Faulty289.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# Imagem: Areial_Faulty47.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Imagem: Areial_Faulty336.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Imagem: Areial_Faulty215.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Areial_Faulty255.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Imagem: Areial_Faulty382.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Imagem: Areial_Faulty608.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Areial_Faulty475.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Areial_Faulty232.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Areial_Faulty717.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Imagem: Areial_Faulty649.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Areial_Faulty431.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Imagem: Areial_Faulty391.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Areial_Faulty669.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Imagem: Areial_Faulty371.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Imagem: Areial_Faulty421.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Imagem: Areial_Faulty441.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Faulty356.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty674.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Areial_Faulty596.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty389.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty671.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty701.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty523.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Areial_Faulty692.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Imagem: Areial_Faulty707.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty639.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty471.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty586.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Areial_Faulty27.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty390.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Areial_Faulty514.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Faulty498.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty61.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty309.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty212.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty65.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Imagem: Areial_Faulty450.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Imagem: Areial_Faulty636.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Faulty612.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty451.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty46.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty308.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Faulty420.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Areial_Faulty415.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty678.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Areial_Faulty423.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty654.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty894.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Areial_Faulty740.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Imagem: Faulty_Validation112.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Faulty792.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty822.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty74.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty972.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation100.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Areial_Faulty748.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation103.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation107.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Faulty887.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation108.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty997.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation114.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Faulty_Validation105.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation110.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty920.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Areial_Faulty865.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Areial_Faulty772.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty95.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty82.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Faulty978.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Faulty773.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty922.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty931.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty842.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty746.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Areial_Faulty873.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty864.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty853.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation109.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation1.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty750.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Areial_Faulty78.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Faulty777.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Areial_Faulty948.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty998.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Areial_Faulty960.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Areial_Faulty73.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation111.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Areial_Faulty724.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Imagem: Faulty_Validation101.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation11.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation10.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Faulty775.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Faulty969.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation115.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Areial_Faulty994.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Faulty883.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation104.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation113.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_Validation102.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation106.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Areial_Faulty863.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Areial_Faulty844.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation124.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_Validation125.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation165.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation133.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation162.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation118.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation157.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation139.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation119.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation14.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation16.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation152.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation140.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Faulty_Validation141.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation160.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation150.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation161.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation131.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation137.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation116.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Imagem: Faulty_Validation120.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Imagem: Faulty_Validation145.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Imagem: Faulty_Validation158.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation128.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation142.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation123.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation156.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation148.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation151.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation147.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation132.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Faulty_Validation129.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation143.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Imagem: Faulty_Validation146.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation117.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation153.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Faulty_Validation164.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Imagem: Faulty_Validation155.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Imagem: Faulty_Validation149.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Faulty_Validation135.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Imagem: Faulty_Validation130.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Faulty_Validation136.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Imagem: Faulty_Validation121.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Imagem: Faulty_Validation12.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Imagem: Faulty_Validation15.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Imagem: Faulty_Validation159.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Faulty_Validation122.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Faulty_Validation13.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Faulty_Validation167.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Faulty_Validation126.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Imagem: Faulty_Validation134.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Imagem: Faulty_Validation138.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Faulty_Validation166.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Imagem: Faulty_Validation163.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Imagem: Faulty_Validation127.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Imagem: Faulty_Validation154.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Faulty_Validation144.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Imagem: Faulty_Validation22.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Imagem: Faulty_Validation198.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Imagem: Faulty_Validation192.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Faulty_Validation183.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Imagem: Faulty_Validation190.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Imagem: Faulty_Validation25.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Faulty_Validation30.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Imagem: Faulty_Validation23.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Imagem: Faulty_Validation186.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Imagem: Faulty_Validation193.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Imagem: Faulty_Validation187.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# Imagem: Faulty_Validation180.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation200.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_Validation31.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation184.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation176.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation33.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation185.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation194.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Imagem: Faulty_Validation169.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation3.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Faulty_Validation21.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation26.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation178.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation175.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation191.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation188.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation2.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation168.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Imagem: Faulty_Validation32.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Faulty_Validation18.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation196.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation174.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation17.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Faulty_Validation199.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation24.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation170.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation172.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_Validation173.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_Validation177.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Faulty_Validation27.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Faulty_Validation179.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Faulty_Validation189.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation195.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation28.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Imagem: Faulty_Validation35.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation36.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation197.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation20.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation182.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation29.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation19.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation34.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation171.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation181.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Imagem: Faulty_Validation52.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation85.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation45.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation80.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation47.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation77.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Faulty_Validation38.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation6.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation59.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation70.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation72.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation69.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation71.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation41.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation42.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation4.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation78.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation57.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation55.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation66.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation5.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Faulty_Validation40.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation60.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation86.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation61.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation8.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation67.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation74.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation73.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Faulty_Validation43.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation58.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation53.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation83.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation49.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Faulty_Validation75.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation68.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation82.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation65.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Faulty_Validation7.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Faulty_Validation76.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation56.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation50.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation54.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation48.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Faulty_Validation81.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation51.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation79.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation62.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation39.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Faulty_Validation63.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation46.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation64.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation44.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation84.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation37.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Faulty_Validation95.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Faulty_Validation96.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation87.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Faulty_Validation91.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Imagem: Faulty_Validation92.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Faulty_Validation94.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Faulty_Validation98.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Faulty_Validation89.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Faulty_Validation93.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Faulty_Validation90.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Imagem: Faulty_Validation88.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Faulty_Validation99.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Faulty_Validation97.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Imagem: Faulty_Validation9.jpg -> Classe Predita: Healthy

# %%
pasta_imagens = "/content/drive/Shareddrives/Letícia Vieira Gonçalves - Pesquisa/dataset/CAI-SWTB-Dataset/Test/Test/Validation/Healthy"  # Substitua pelo caminho correto
valid_extensions = (".jpg", ".jpeg", ".png", ".bmp")

# Mapeamento das classes
mapping = {0: "Faulty", 1: "Healthy"}

# Percorrer todas as imagens da pasta
for nome_arquivo in os.listdir(pasta_imagens):
    if nome_arquivo.lower().endswith(valid_extensions):  # Verifica se é uma imagem
        caminho_imagem = os.path.join(pasta_imagens, nome_arquivo)

        # Pré-processar a imagem
        imagem = preprocessar_imagem(caminho_imagem)

        # Fazer a predição
        predicao = modelo.predict(imagem)
        classe_predita = np.argmax(predicao)  # Obtém a classe com maior probabilidade

        print(f"Imagem: {nome_arquivo} -> Classe Predita: {mapping[classe_predita]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy141.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Healthy151.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Areial_Healthy379.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Imagem: Areial_Healthy337.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Imagem: Areial_Healthy134.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Imagem: Areial_Healthy26.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Areial_Healthy449.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Areial_Healthy218.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Healthy27.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Imagem: Areial_Healthy214.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy406.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Areial_Healthy357.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Imagem: Areial_Healthy317.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Imagem: Areial_Healthy256.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Areial_Healthy231.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Imagem: Areial_Healthy3.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Imagem: Areial_Healthy250.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Areial_Healthy215.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Imagem: Areial_Healthy319.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Imagem: Areial_Healthy205.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Areial_Healthy322.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Imagem: Areial_Healthy104.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Areial_Healthy209.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Imagem: Areial_Healthy120.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Imagem: Areial_Healthy137.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Areial_Healthy448.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Imagem: Areial_Healthy159.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Areial_Healthy43.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Imagem: Areial_Healthy31.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# Imagem: Areial_Healthy348.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Imagem: Areial_Healthy13.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Areial_Healthy142.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Imagem: Areial_Healthy419.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Areial_Healthy288.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Imagem: Areial_Healthy421.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Imagem: Areial_Healthy143.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Imagem: Areial_Healthy300.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Imagem: Areial_Healthy261.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Areial_Healthy203.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy380.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Areial_Healthy311.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Areial_Healthy420.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Areial_Healthy42.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Healthy331.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy779.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy721.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy791.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Areial_Healthy753.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Healthy718.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Imagem: Areial_Healthy804.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy856.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Healthy912.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy740.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Imagem: Areial_Healthy544.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy625.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy899.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Healthy647.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Healthy481.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy611.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Healthy764.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Areial_Healthy629.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Areial_Healthy555.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Healthy547.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Healthy453.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Areial_Healthy572.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation1.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Areial_Healthy989.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Healthy606.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy633.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy690.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Healthy961.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Imagem: Areial_Healthy684.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Healthy512.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Areial_Healthy814.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy527.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Imagem: Areial_Healthy862.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Healthy51.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Areial_Healthy917.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Areial_Healthy569.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Areial_Healthy507.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy709.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Healthy902.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Healthy620.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Imagem: Areial_Healthy725.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy780.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Healthy76.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Healthy729.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy542.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy641.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Areial_Healthy866.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Areial_Healthy79.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation10.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy540.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Areial_Healthy897.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Areial_Healthy659.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Imagem: Areial_Healthy660.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Imagem: Areial_Healthy936.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Areial_Healthy78.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Imagem: Areial_Healthy949.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Imagem: Areial_Healthy732.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Areial_Healthy464.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Areial_Healthy981.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation129.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation109.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation114.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation111.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Imagem: Healthy_Validation151.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation126.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation112.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation131.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation121.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Healthy_Validation152.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation102.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation104.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation125.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_Validation134.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation116.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation122.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation142.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Healthy_Validation120.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation133.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Imagem: Healthy_Validation103.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_Validation13.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Healthy_Validation132.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation117.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation143.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation115.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation106.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation110.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Imagem: Healthy_Validation119.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation137.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation123.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation138.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_Validation148.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Imagem: Healthy_Validation11.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation145.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation149.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Healthy_Validation140.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation141.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation150.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Healthy_Validation100.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Imagem: Healthy_Validation15.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation124.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation118.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation136.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation113.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_Validation108.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Imagem: Healthy_Validation146.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_Validation130.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation144.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation128.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation14.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_Validation139.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation12.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation101.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation127.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Imagem: Healthy_Validation105.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Healthy_Validation147.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Imagem: Healthy_Validation135.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Imagem: Healthy_Validation107.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Imagem: Healthy_Validation175.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# Imagem: Healthy_Validation189.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Healthy_Validation17.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Healthy_Validation156.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Imagem: Healthy_Validation197.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Imagem: Healthy_Validation181.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Healthy_Validation200.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Imagem: Healthy_Validation19.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Imagem: Healthy_Validation163.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Healthy_Validation184.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Healthy_Validation167.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Imagem: Healthy_Validation153.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Imagem: Healthy_Validation159.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Imagem: Healthy_Validation169.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Imagem: Healthy_Validation161.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Imagem: Healthy_Validation192.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Imagem: Healthy_Validation20.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Imagem: Healthy_Validation196.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Healthy_Validation183.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Imagem: Healthy_Validation173.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Imagem: Healthy_Validation165.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Imagem: Healthy_Validation155.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Healthy_Validation178.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Imagem: Healthy_Validation23.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Imagem: Healthy_Validation166.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Imagem: Healthy_Validation186.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Healthy_Validation195.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_Validation18.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Healthy_Validation158.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation182.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation191.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation160.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation171.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation180.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation193.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_Validation187.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Healthy_Validation176.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation190.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation154.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_Validation172.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Imagem: Healthy_Validation170.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation177.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation162.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation185.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation198.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation21.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation157.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_Validation199.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_Validation174.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation194.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation22.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_Validation16.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Healthy_Validation188.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation179.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation168.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation164.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Healthy_Validation2.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation27.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_Validation70.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation7.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation62.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation5.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation66.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Imagem: Healthy_Validation29.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation57.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_Validation50.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation55.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Imagem: Healthy_Validation71.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Healthy_Validation3.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation4.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation58.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_Validation33.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation48.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_Validation68.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Imagem: Healthy_Validation25.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Healthy_Validation73.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation38.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation35.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation26.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation65.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation39.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation34.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Imagem: Healthy_Validation51.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation69.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation63.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Imagem: Healthy_Validation53.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_Validation37.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation36.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation60.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation54.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation56.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Healthy_Validation40.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation32.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation64.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_Validation52.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation45.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Imagem: Healthy_Validation28.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Healthy_Validation61.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation24.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation41.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation59.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation75.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_Validation49.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation31.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Imagem: Healthy_Validation43.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Imagem: Healthy_Validation67.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_Validation6.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Imagem: Healthy_Validation42.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Healthy_Validation46.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Imagem: Healthy_Validation30.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation72.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_Validation44.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_Validation74.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_Validation47.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_Validation81.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation95.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation93.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Healthy_Validation87.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Imagem: Healthy_Validation99.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation92.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation79.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation90.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Imagem: Healthy_Validation82.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Imagem: Healthy_Validation88.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation76.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation8.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_Validation97.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_Validation77.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation89.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation98.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Imagem: Healthy_Validation96.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation85.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation94.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Imagem: Healthy_Validation80.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# Imagem: Healthy_Validation83.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Imagem: Healthy_Validation9.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Imagem: Healthy_Validation86.jpg -> Classe Predita: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Imagem: Healthy_Validation91.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Imagem: Healthy_Validation84.jpg -> Classe Predita: Faulty
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Imagem: Healthy_Validation78.jpg -> Classe Predita: Healthy

# %% [markdown]
# Teste do modelo - Maneira mais

# %%
# Função para pré-processar imagens
def preprocessar_imagem(caminho_imagem):
    image_width, image_height = 48, 48  # Tamanho usado no treinamento
    img = cv2.imread(caminho_imagem)
    img = cv2.resize(img, (image_width, image_height))
    img = img.astype("float32") / 255.0  # Normalização
    img = np.expand_dims(img, axis=0)  # Adicionar batch dimension
    return img

# Diretório com as imagens
pasta_imagens = "/content/drive/Shareddrives/Letícia Vieira Gonçalves - Pesquisa/dataset/CAI-SWTB-Dataset/Test/Test/Test"  # Substitua pelo caminho correto
valid_extensions = (".jpg", ".jpeg", ".png", ".bmp")

# Mapeamento das classes
mapping = {0: "Faulty", 1: "Healthy"}

# Lista para armazenar os resultados
resultados = []

# Percorrer todas as imagens da pasta
for nome_arquivo in os.listdir(pasta_imagens):
    if nome_arquivo.lower().endswith(valid_extensions):  # Verifica se é uma imagem
        caminho_imagem = os.path.join(pasta_imagens, nome_arquivo)

        # Pré-processar a imagem
        imagem = preprocessar_imagem(caminho_imagem)

        # Fazer a predição
        predicao = modelo.predict(imagem)
        classe_predita = np.argmax(predicao)  # Obtém a classe com maior probabilidade
        classe_str = mapping[classe_predita]

        # Adicionar à lista de resultados
        resultados.append([nome_arquivo, classe_str])

# Criar um DataFrame do Pandas
df = pd.DataFrame(resultados, columns=["Imagem", "Classe Predita"])

# Salvar em um arquivo CSV
caminho_csv = "resultClassification.csv"
df.to_csv(caminho_csv, index=False)

# Contar a quantidade de cada classe
contagem_classes = df["Classe Predita"].value_counts()

# Exibir os resultados
print(f"Classificação salva em: {caminho_csv}")
print("\nQuantidade de imagens por classe:")
print(contagem_classes)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Classificação salva em: resultClassification.csv
#
# Quantidade de imagens por classe:
# Classe Predita
# Faulty     177
# Healthy     23
# Name: count, dtype: int64
